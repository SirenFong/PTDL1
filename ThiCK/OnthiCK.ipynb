# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('data/dulieuxettuyendaihoc.csv', header=0,delimiter=',', encoding='utf-8')
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0                3.25            4.50  A1  12/7/2018                  No
# ...

# %%
df.head(10)
# Out:
#      MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0   SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1   SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2   SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3   SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4   SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# 5   SV006  9.3  9.6  7.1  8.5  8.5  7.8  M NaN    1     1.50
# 6   SV007  2.8  4.4  4.6  4.7  5.4  5.3  F NaN    2     6.50
# 7   SV008  8.3  6.7  8.6  8.3  8.5  8.3  F NaN    2     3.75
# 8   SV009  6.5  7.3  6.4  8.1  7.7  7.7  F NaN    1     3.50
# 9  SV0010  7.3  8.0  6.5  5.5  7.5  6.9  F NaN    1     4.00
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# ...

# %%
#đổi tên
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  LOGIC  UNGXU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25   3.25   4.50
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00   4.00   3.50
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00   6.75   4.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25   4.25   5.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25   4.50   5.00
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...    ...    ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25   1.50   6.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25   3.75   4.75
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00   8.00   4.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00   3.50   5.50
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25   2.50   4.25
#
#     KT    NGAYTHI HUONGNGHIEP
# ...

# %%
df.groupby('LOGIC')[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'GT']].describe()
# Out:
#          T1                                                      T2            \
#       count      mean       std  min    25%   50%    75%  max count      mean
# LOGIC
# 1.50    1.0  8.600000       NaN  8.6  8.600  8.60  8.600  8.6   1.0  8.900000
# 2.00    1.0  3.600000       NaN  3.6  3.600  3.60  3.600  3.6   1.0  4.200000
# 2.25    2.0  4.550000  3.040559  2.4  3.475  4.55  5.625  6.7   2.0  4.950000
# 2.50    2.0  4.950000  1.202082  4.1  4.525  4.95  5.375  5.8   2.0  5.400000
# 2.75    2.0  5.650000  1.060660  4.9  5.275  5.65  6.025  6.4   2.0  5.200000
# 3.00    3.0  3.966667  1.305118  2.5  3.450  4.40  4.700  5.0   3.0  5.466667
# 3.25    2.0  6.600000  0.848528  6.0  6.300  6.60  6.900  7.2   2.0  7.850000
# 3.50   15.0  6.106667  1.501650  2.7  5.150  6.50  7.250  8.2  15.0  6.606667
# 3.75    7.0  4.985714  1.386156  3.0  4.100  5.30  5.650  7.1   7.0  5.542857
# 4.00   15.0  6.426667  1.732243  3.6  5.200  6.10  8.000  9.3  15.0  6.673333
# ...

# %%
X= df[['T1', 'T2', 'T3', 'T4', 'T5', 'T6','GT']].values #input
y= df[['LOGIC']].values #output

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state=16)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Study\Lập trình phân tích dữ liệu 1\LTPTDL\Code\ThiCK\OnthiCK.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/d%3A/Study/L%E1%BA%ADp%20tr%C3%ACnh%20ph%C3%A2n%20t%C3%ADch%20d%E1%BB%AF%20li%E1%BB%87u%201/LTPTDL/Code/ThiCK/OnthiCK.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import MinMaxScaler
#       <a href='vscode-notebook-cell:/d%3A/Study/L%E1%BA%ADp%20tr%C3%ACnh%20ph%C3%A2n%20t%C3%ADch%20d%E1%BB%AF%20li%E1%BB%87u%201/LTPTDL/Code/ThiCK/OnthiCK.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> sc = MinMaxScaler()
# ----> <a href='vscode-notebook-cell:/d%3A/Study/L%E1%BA%ADp%20tr%C3%ACnh%20ph%C3%A2n%20t%C3%ADch%20d%E1%BB%AF%20li%E1%BB%87u%201/LTPTDL/Code/ThiCK/OnthiCK.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> X = sc.fit_transform(X)
#
# ...
