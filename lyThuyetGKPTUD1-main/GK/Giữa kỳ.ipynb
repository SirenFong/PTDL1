# %%
'''
    Đại cương Phân tích dữ liệu
    Mục đích: Khám phá trí thức  (thông tin) từ dữ liệu nhầm hỗ trợ các quyết định 
    và nhận thức của con người trong nhiều lĩnh vực: kinh tế, xã hội,....

    Công cụ phân tích dữ liệu:
    1.Công cụ giao diện cho người không chuyên: SPSS, Excel...
    2.Công cụ dành cho chuyên gia nhưng không phải CNTT: R tool, SaSS,.....
    3.Công cụ dành cho CNTT: Python,...

    Quy trình phân tích dữ liệu: Thông thường có các bước sau đây:
    1.Xác định được múc đích hay còn gọi là bài toán cần giải quyết liên quan đến PTDL
    2.Thu thập dữ liệu từ các nguồn: Sơ cấp và nguồn thứ cấp
        - Sơ cấp là nguồn thô tự chúng ta xây dựng. 
            + Đặc điểm: tốn chi phí, đa dạng theo nhu cầu, có nhiều lỗi. 
            + Cách thu thập: lập bản khảo sát, viết tôl để cào web, phát tờ rơi,...
        - Thứ cấp: đay là nguồn được cung cấp bởi bên thứ 3, tổ chức có uy tín
            + Đặc điểm: không đa dạng theo yêu cầu, dữ liệu ít lỗi vì đã được xử lý, tốn kém chi phí
            + Cách thu thập: Tool để cào dữ liệu trên web: beaaty soup, scrapy, selineum,...
    3.Thực hiện xữ lý dữ liệu: 
        - Hiểu dữ liệu: ý nghĩa của các biến số (cột dữ liệu), cách tổ chức dữ liệu, kiểu dữ liệu, loại dữ liệu (định tính hay định lượng) và
        các thang đo thông tin (dịnh danh, phân loại, thứ bậc, khoảng, tỉ lệ)
        - Xử lý dữ liệu cơ bản: thiếu, rỗng, lỗi,...Trộn dữ liệu, tích hợp dữ liệu, giảm số lượng dữ liệu, loại bỏ dữ liệu thừa,...
    4.Khám phá dữ liệu (Explanatory Data Analysis): bung thông tin đang được chứa đựng trong dữ liệu bảng các kỹ thuật như: tổng hợp dữ
    liệu (summarize), đồ họa (visualization)
    5.Xây mô hình máy học: nầm phục vụ cho bài toán cụ thể. Thồn thường có 4 bài toán
        - Hồi quy (mục đích dự đoán)
        - Phân lớp (múc đích phân loại)
        - Gom cụm
        - Luật kết hợp
    6.Đánh giá mô hình: sử dụng các kỹ thuật tían hoặc nghiệp vụ để đánh giá sự hiệu quả của mô hình trong bước 5
    7.Phản hồi (Feedback): triển khai mô hình ra thực tế và nhận phản hồi của khách hàng

'''
# Out:
# '\n    Đại cương Phân tích dữ liệu\n    Mục đích: Khám phá trí thức  (thông tin) từ dữ liệu nhầm hỗ trợ các quyết định \n    và nhận thức của con người trong nhiều lĩnh vực: kinh tế, xã hội,....\n\n    Công cụ phân tích dữ liệu:\n    1.Công cụ giao diện cho người không chuyên: SPSS, Excel...\n    2.Công cụ dành cho chuyên gia nhưng không phải CNTT: R tool, SaSS,.....\n    3.Công cụ dành cho CNTT: Python,...\n\n    Quy trình phân tích dữ liệu: Thông thường có các bước sau đây:\n    1.Xác định được múc đích hay còn gọi là bài toán cần giải quyết liên quan đến PTDL\n    2.Thu thập dữ liệu từ các nguồn: Sơ cấp và nguồn thứ cấp\n        - Sơ cấp là nguồn thô tự chúng ta xây dựng. \n            + Đặc điểm: tốn chi phí, đa dạng theo nhu cầu, có nhiều lỗi. \n            + Cách thu thập: lập bản khảo sát, viết tôl để cào web, phát tờ rơi,...\n        - Thứ cấp: đay là nguồn được cung cấp bởi bên thứ 3, tổ chức có uy tín\n            + Đặc điểm: không đa dạng theo yêu cầu, dữ liệu ít lỗi vì đã
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('dulieuxettuyendaihoc.csv', header=0,delimiter=',', encoding='utf-8')
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0                3.25            4.50  A1  12/7/2018                  No
# ...

# %%
#10 dòng đầu
df.head(10)
# Out:
#      MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0   SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1   SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2   SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3   SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4   SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# 5   SV006  9.3  9.6  7.1  8.5  8.5  7.8  M NaN    1     1.50
# 6   SV007  2.8  4.4  4.6  4.7  5.4  5.3  F NaN    2     6.50
# 7   SV008  8.3  6.7  8.6  8.3  8.5  8.3  F NaN    2     3.75
# 8   SV009  6.5  7.3  6.4  8.1  7.7  7.7  F NaN    1     3.50
# 9  SV0010  7.3  8.0  6.5  5.5  7.5  6.9  F NaN    1     4.00
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# ...

# %%
#10 dòng cuối
df.tail(10)
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 90   SV0091  8.1  8.8  9.2  8.8  8.9  8.5  M NaN    2     6.25
# 91   SV0092  7.8  8.9  8.5  7.8  8.6  9.4  M NaN  2NT     4.75
# 92   SV0093  5.0  6.8  7.2  6.1  8.0  7.5  M NaN    1     3.25
# 93   SV0094  5.2  6.8  6.7  6.6  7.3  7.3  M NaN    1     3.50
# 94   SV0095  5.8  6.4  7.3  7.1  7.3  6.7  M NaN    1     4.25
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  GIAIQUYETVANDE KT    NGAYTHI DINHHUONGNGHENGHIEP
# 90               4.00            6.50  A  7/20/2022                 Yes
# 91               4.75            4.50  A  7/20/2022                  No
# ...

# %%
#in cột
df.columns
# Out:
# Index(['MSSV', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'GT', 'DT', 'KV', 'NGONNGU',
#        'TOANLOGICPHANTICH', 'GIAIQUYETVANDE', 'KT', 'NGAYTHI',
#        'DINHHUONGNGHENGHIEP'],
#       dtype='object')

# %%
#đổi tên
df.rename(columns={'TOANLOGiCPHANTICH': 'TOAN', 'GIAIQUYETVANDE':'KYNANG','DINHHUONGNGHENGHIEP': 'HUONGNGHIEP'}, inplace=True)
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  KYNANG  KT    NGAYTHI HUONGNGHIEP
# 0                3.25    4.50  A1  12/7/2018          No
# 1                4.00    3.50   C  12/7/2018         Yes
# ...

# %%
#Kiểu dữ liệu
df.dtypes
# Out:
# MSSV                  object
# T1                   float64
# T2                   float64
# T3                   float64
# T4                   float64
# T5                   float64
# T6                   float64
# GT                    object
# DT                   float64
# KV                    object
# NGONNGU              float64
# TOANLOGICPHANTICH    float64
# KYNANG               float64
# KT                    object
# NGAYTHI               object
# HUONGNGHIEP           object
# dtype: object

# %%
#Kích thước
df.shape
# Out:
# (100, 16)

# %%
#
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
#xem thông tin
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSSV               100 non-null    object
#  1   T1                 100 non-null    float64
#  2   T2                 100 non-null    float64
#  3   T3                 100 non-null    float64
#  4   T4                 100 non-null    float64
#  5   T5                 100 non-null    float64
#  6   T6                 100 non-null    float64
#  7   GT                 100 non-null    object
#  8   DT                 3 non-null      float64
#  9   KV                 100 non-null    object
#  10  NGONNGU            100 non-null    float64
#  11  TOANLOGICPHANTICH  100 non-null    float64
#  12  KYNANG             100 non-null    float64
#  13  KT                 100 non-null    object
#  14  NGAYTHI            100 non-null    object
#  15  HUONGNGHIEP        100 non-null    object
# ...

# %%
#phân biệt sự khác nhau giữa df['T1] và df[['T1']]
df['T1']
# Out:
# 0     7.2
# 1     5.4
# 2     5.6
# 3     6.6
# 4     6.0
#      ...
# 95    8.6
# 96    3.7
# 97    8.8
# 98    2.7
# 99    4.1
# Name: T1, Length: 100, dtype: float64

# %%
df[['T1']]
# Out:
#      T1
# 0   7.2
# 1   5.4
# 2   5.6
# 3   6.6
# 4   6.0
# ..  ...
# 95  8.6
# 96  3.7
# 97  8.8
# 98  2.7
# 99  4.1
#
# [100 rows x 1 columns]

# %%
#lấy dữ liệu theo cột
df_T5T6=df[['T5','T6','KV', 'KT']]
df_T5T6
# Out:
#      T5   T6   KV  KT
# 0   7.4  6.9  2NT  A1
# 1   3.0  4.0    1   C
# 2   4.8  5.7    1   C
# 3   6.1  7.4    1  D1
# 4   6.8  8.0  2NT   A
# ..  ...  ...  ...  ..
# 95  7.9  6.6    1   C
# 96  5.5  5.7    1   C
# 97  9.0  8.5  2NT   C
# 98  4.1  4.3    1   C
# 99  5.6  5.1  2NT   C
#
# [100 rows x 4 columns]

# %%
#lấy tất cả dòng dữ liệu có index=2 đến index=96
df_T5T6[2:97]
# Out:
#      T5   T6   KV  KT
# 2   4.8  5.7    1   C
# 3   6.1  7.4    1  D1
# 4   6.8  8.0  2NT   A
# 5   8.5  7.8    1  D1
# 6   5.4  5.3    2   C
# ..  ...  ...  ...  ..
# 92  8.0  7.5    1   A
# 93  7.3  7.3    1   A
# 94  7.3  6.7    1   A
# 95  7.9  6.6    1   C
# 96  5.5  5.7    1   C
#
# [95 rows x 4 columns]

# %%
#lấy dữ liệu dòng 92
df_T5T6.loc[92]
# Out:
# T5    8.0
# T6    7.5
# KV      1
# KT      A
# Name: 92, dtype: object

# %%
#lấy dữ liệu có index=4 đến index=10
df_T5T6.loc[4:10]
# Out:
#      T5   T6   KV  KT
# 4   6.8  8.0  2NT   A
# 5   8.5  7.8    1  D1
# 6   5.4  5.3    2   C
# 7   8.5  8.3    2  D1
# 8   7.7  7.7    1  D1
# 9   7.5  6.9    1  D1
# 10  6.2  7.3    2  D1

# %%
#lấy dữ liệu index=5 đến index=9 cụ thể trên các cột T6, KT
df_T5T6.loc[5:9,['T6','KT']]
# Out:
#     T6  KT
# 5  7.8  D1
# 6  5.3   C
# 7  8.3  D1
# 8  7.7  D1
# 9  6.9  D1

# %%
#lấy dữ liệu theo index dòng 5
df_T5T6.iloc[5]
# Out:
# T5    8.5
# T6    7.8
# KV      1
# KT     D1
# Name: 5, dtype: object

# %%
#lấy dữ liệu index=6 đến index=8
df_T5T6.iloc[6:9]
# Out:
#     T5   T6 KV  KT
# 6  5.4  5.3  2   C
# 7  8.5  8.3  2  D1
# 8  7.7  7.7  1  D1

# %%
#lay tu index=0 den 4
df_T5T6.iloc[:5]
# Out:
#     T5   T6   KV  KT
# 0  7.4  6.9  2NT  A1
# 1  3.0  4.0    1   C
# 2  4.8  5.7    1   C
# 3  6.1  7.4    1  D1
# 4  6.8  8.0  2NT   A

# %%
#lay tu chi so 95 den het
df_T5T6.iloc[95:]
# Out:
#      T5   T6   KV KT
# 95  7.9  6.6    1  C
# 96  5.5  5.7    1  C
# 97  9.0  8.5  2NT  C
# 98  4.1  4.3    1  C
# 99  5.6  5.1  2NT  C

# %%
#lấy dữ liệu theo dòng và cột
#dòng từ 2 đến 4
#cột từ 1 đến 2
df_T5T6.iloc[2:5, 1:3]
# Out:
#     T6   KV
# 2  5.7    1
# 3  7.4    1
# 4  8.0  2NT

# %%
#sắp xếp dữ liệu tăng dần
df_T5T6.sort_values(by='T5', ascending=True)
# Out:
#      T5   T6   KV  KT
# 1   3.0  4.0    1   C
# 37  3.2  3.7    2   A
# 22  3.4  4.1    2   C
# 15  3.4  5.3    1  D1
# 69  3.5  5.6    1   B
# ..  ...  ...  ...  ..
# 90  8.9  8.5    2   A
# 97  9.0  8.5  2NT   C
# 20  9.3  8.4    1   A
# 12  9.3  8.3    1  D1
# 55  9.5  9.5  2NT  A1
#
# [100 rows x 4 columns]

# %%
#sắp xếp dữ liệu giảm dần
df_T5T6.sort_values(by='T5', ascending=False)
# Out:
#      T5   T6   KV  KT
# 55  9.5  9.5  2NT  A1
# 12  9.3  8.3    1  D1
# 20  9.3  8.4    1   A
# 97  9.0  8.5  2NT   C
# 90  8.9  8.5    2   A
# ..  ...  ...  ...  ..
# 69  3.5  5.6    1   B
# 15  3.4  5.3    1  D1
# 22  3.4  4.1    2   C
# 37  3.2  3.7    2   A
# 1   3.0  4.0    1   C
#
# [100 rows x 4 columns]

# %%
#sap xep ascending (true: tang, false: giam)
df_T5T6.sort_values(by=['T5','T6'], ascending=[True,False])
# Out:
#      T5   T6   KV  KT
# 1   3.0  4.0    1   C
# 37  3.2  3.7    2   A
# 15  3.4  5.3    1  D1
# 22  3.4  4.1    2   C
# 69  3.5  5.6    1   B
# ..  ...  ...  ...  ..
# 90  8.9  8.5    2   A
# 97  9.0  8.5  2NT   C
# 20  9.3  8.4    1   A
# 12  9.3  8.3    1  D1
# 55  9.5  9.5  2NT  A1
#
# [100 rows x 4 columns]

# %%
#lấy dữ liệu có điều kiện
a=df_T5T6[df_T5T6['T6']>=8]
#tăng dần 
a.sort_values(by='T6', ascending=True)
# Out:
#      T5   T6   KV  KT
# 4   6.8  8.0  2NT   A
# 31  6.3  8.0    1   A
# 68  8.4  8.1    1   B
# 36  7.8  8.1    1   A
# 47  8.6  8.1    2   A
# 11  8.0  8.1    2  D1
# 83  5.5  8.2    1   B
# 70  6.5  8.2    2   A
# 12  9.3  8.3    1  D1
# 7   8.5  8.3    2  D1
# 20  9.3  8.4    1   A
# 28  8.3  8.4  2NT   A
# 18  6.6  8.5    1   A
# 90  8.9  8.5    2   A
# 74  8.0  8.5    1   A
# 97  9.0  8.5  2NT   C
# 41  8.8  8.5    2   A
# 14  8.6  8.5  2NT   A
# 84  8.2  8.6    1   A
# 56  8.5  8.7    1   A
# 19  7.1  8.9    2   A
# 61  7.9  8.9    1   A
# 71  6.8  9.0    1   B
# 80  8.7  9.3  2NT   A
# 91  8.6  9.4  2NT   A
# 55  9.5  9.5  2NT  A1

# %%
#lấy dữ liệu có điều kiện và
df_T5T6[(df_T5T6['T5']>7) & (df_T5T6['T6']>8)]
# Out:
#      T5   T6   KV  KT
# 7   8.5  8.3    2  D1
# 11  8.0  8.1    2  D1
# 12  9.3  8.3    1  D1
# 14  8.6  8.5  2NT   A
# 19  7.1  8.9    2   A
# 20  9.3  8.4    1   A
# 28  8.3  8.4  2NT   A
# 36  7.8  8.1    1   A
# 41  8.8  8.5    2   A
# 47  8.6  8.1    2   A
# 55  9.5  9.5  2NT  A1
# 56  8.5  8.7    1   A
# 61  7.9  8.9    1   A
# 68  8.4  8.1    1   B
# 74  8.0  8.5    1   A
# 80  8.7  9.3  2NT   A
# 84  8.2  8.6    1   A
# 90  8.9  8.5    2   A
# 91  8.6  9.4  2NT   A
# 97  9.0  8.5  2NT   C

# %%
#lấy dữ liệu số sinh viên có khối thi = c 
df_T5T6.loc[df_T5T6['KT']=='C']
# Out:
#      T5   T6   KV KT
# 1   3.0  4.0    1  C
# 2   4.8  5.7    1  C
# 6   5.4  5.3    2  C
# 22  3.4  4.1    2  C
# 23  5.3  6.1  2NT  C
# 24  4.4  3.8    1  C
# 25  5.8  3.7    1  C
# 26  6.1  6.8    1  C
# 27  5.8  5.6  2NT  C
# 95  7.9  6.6    1  C
# 96  5.5  5.7    1  C
# 97  9.0  8.5  2NT  C
# 98  4.1  4.3    1  C
# 99  5.6  5.1  2NT  C

# %%
#kích thuóc (dòng x cột)
df_T5T6.loc[df_T5T6['KT']=='C'].shape
# Out:
# (14, 4)

# %%
#Part: data Aggregation
# lưu ý với sinh viên về các hàm tổng hợp tên các loại biến định tính và định lượng
df_T5T6.aggregate({'T5':['min','max'], 'T6':['mean','sum']})
# Out:
#        T5       T6
# min   3.0      NaN
# max   9.5      NaN
# mean  NaN    6.937
# sum   NaN  693.700

# %%
#gom nhóm
#Nguyên tắc gom nhóm: KV: luôn là biến định tính, tùy theo biến mà chọn hàm agg cho phù hợp

#gom nhóm đếm KV theo KV
df_T5T6.groupby(['KV'])['KV'].agg(['count'])
# Out:
#      count
# KV
# 1       60
# 2       19
# 2NT     21

# %%
#gom nhóm đếm, min, max, mean, std (độ lệch chuẩn), sum     KV theo T5
df_T5T6.groupby(['KV'])['T5'].agg(['count','min','mean','std','max','sum'])
# Out:
#      count  min      mean       std  max    sum
# KV
# 1       60  3.0  6.515000  1.501053  9.3  390.9
# 2       19  3.2  6.784211  1.574189  8.9  128.9
# 2NT     21  5.3  7.233333  1.237066  9.5  151.9

# %%
#gom nhóm min, mean KV theo T5,T6
df_T5T6.groupby(['KV'])[['T5','T6']].agg(['min','mean'])
# Out:
#       T5             T6
#      min      mean  min      mean
# KV
# 1    3.0  6.515000  3.7  6.743333
# 2    3.2  6.784211  3.7  7.105263
# 2NT  5.3  7.233333  5.1  7.338095

# %%
#gom nhóm min, max  KV,KT  theo T5,T6
df_T5T6.groupby(['KV','KT'])[['T5','T6']].agg(['min','max'])
# Out:
#          T5        T6
#         min  max  min  max
# KV  KT
# 1   A   4.7  9.3  4.0  8.9
#     A1  7.4  7.8  6.4  7.1
#     B   3.5  8.4  5.2  9.0
#     C   3.0  7.9  3.7  6.8
#     D1  3.4  9.3  4.9  8.3
# 2   A   3.2  8.9  3.7  8.9
#     C   3.4  5.4  4.1  5.3
#     D1  5.8  8.5  6.0  8.3
# 2NT A   5.8  8.7  5.7  9.4
#     A1  6.7  9.5  6.6  9.5
#     B   7.8  7.8  6.9  6.9
#     C   5.3  9.0  5.1  8.5
#     D1  7.4  7.4  5.9  5.9

# %%
#tạo bảng pivot_table
pd.pivot_table(df_T5T6,
               values=['T5','T6'],
               columns='KV', aggfunc=['min','mean','max'])
# Out:
#     min                mean                      max
# KV    1    2  2NT         1         2       2NT    1    2  2NT
# T5  3.0  3.2  5.3  6.515000  6.784211  7.233333  9.3  8.9  9.5
# T6  3.7  3.7  5.1  6.743333  7.105263  7.338095  9.0  8.9  9.5

# %%
#tạo bảng pivot_table
pd.pivot_table(df_T5T6,
               values=['T5','T6'],
               columns=['KV','KT'], aggfunc=['min','mean','max'])
# Out:
#     min                                               ...  max                 \
# KV    1                        2            2NT       ...    1         2
# KT    A   A1    B    C   D1    A    C   D1    A   A1  ...    C   D1    A    C
# T5  4.7  7.4  3.5  3.0  3.4  3.2  3.4  5.8  5.8  6.7  ...  7.9  9.3  8.9  5.4
# T6  4.0  6.4  5.2  3.7  4.9  3.7  4.1  6.0  5.7  6.6  ...  6.8  8.3  8.9  5.3
#
#
# KV       2NT
# KT   D1    A   A1    B    C   D1
# T5  8.5  8.7  9.5  7.8  9.0  7.4
# T6  8.3  9.4  9.5  6.9  8.5  5.9
#
# [2 rows x 39 columns]

# %%
#tìm các giá trị Null
df.isnull().sum()
#thay thế các giá trị Null
import numpy as np
df.replace(np.nan,'0',inplace = True)
#kiểm tra sự thay đổi
df.isnull().sum()
# Out:
# MSSV                 0
# T1                   0
# T2                   0
# T3                   0
# T4                   0
# T5                   0
# T6                   0
# GT                   0
# DT                   0
# KV                   0
# NGONNGU              0
# TOANLOGICPHANTICH    0
# KYNANG               0
# KT                   0
# NGAYTHI              0
# HUONGNGHIEP          0
# dtype: int64

# %%
#EDA

# %%
'''
    Exploratory data analysis (EDA)
    Mục đích: bao gồm các kỹ thuật khám phá dữ liệu 
    (tức là từ dữ liệu rút trích các tri thức, hiểu biết),
    thông qua các biểu đòo và số liệu thống kê với nhièu góc nhìn khác nhau

    Lưu ý: để rút trích thông tin, tri thức dữ liêu,
    người ta thường dùng các đại lượng tổng hợp 
    (count,min,max,sum,mean,std,...)
    hoặc biểu đồ trực quan

    Yêu Cầu: sử dụng dulieuxettuyendaihoc.csv
    hãy phân tích tác động của điểm toán lớp 12 với điểm 
    thi đánh giá năng lực rên các nhóm (đinh tính) GT, KV, KT, DT,
   biết rằng mặc định DT là KINH
'''
# Out:
# '\n    Exploratory data analysis (EDA)\n    Mục đích: bao gồm các kỹ thuật khám phá dữ liệu \n    (tức là từ dữ liệu rút trích các tri thức, hiểu biết),\n    thông qua các biểu đòo và số liệu thống kê với nhièu góc nhìn khác nhau\n\n    Lưu ý: để rút trích thông tin, tri thức dữ liêu,\n    người ta thường dùng các đại lượng tổng hợp \n    (count,min,max,sum,mean,std,...)\n    hoặc biểu đồ trực quan\n\n    Yêu Cầu: sử dụng dulieuxettuyendaihoc.csv\n    hãy phân tích tác động của điểm toán lớp 12 với điểm \n    thi đánh giá năng lực rên các nhóm (đinh tính) GT, KV, KT, DT,\n   biết rằng mặc định DT là KINH\n'

# %%
'''
    Phần 1: Thao tác cơ bản
    B1: Xử lý cơ bản
    1. Xác định số lượng yếu tố (biến số) tham gia vào yêu cầu
    2. Thu thập dữ liệu (Data Collection)
    3. Tổng quan dữ liệu
    4. Xử lý cơ bản
        - Loại bỏ dòng rỗng
        - loại bỏ dìng trùng
        - Khảo sát dữu liệu thiếu
        - Xử lý dữ liệu thiếu
    5. Kiểm tra lại dữ liệu
'''
# Out:
# '\n    Phần 1: Thao tác cơ bản\n    B1: Xử lý cơ bản\n    1. Xác định số lượng yếu tố (biến số) tham gia vào yêu cầu\n    2. Thu thập dữ liệu (Data Collection)\n    3. Tổng quan dữ liệu\n    4. Xử lý cơ bản\n        - Loại bỏ dòng rỗng\n        - loại bỏ dìng trùng\n        - Khảo sát dữu liệu thiếu\n        - Xử lý dữ liệu thiếu\n    5. Kiểm tra lại dữ liệu\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dulieuxettuyendaihoc.csv', 
               header=0, delimiter=',', 
               encoding='utf-8')
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25
#
#     TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0                3.25            4.50  A1  12/7/2018                  No
# ...

# %%
#in ra thông tin
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MSSV                 100 non-null    object
#  1   T1                   100 non-null    float64
#  2   T2                   100 non-null    float64
#  3   T3                   100 non-null    float64
#  4   T4                   100 non-null    float64
#  5   T5                   100 non-null    float64
#  6   T6                   100 non-null    float64
#  7   GT                   100 non-null    object
#  8   DT                   3 non-null      float64
#  9   KV                   100 non-null    object
#  10  NGONNGU              100 non-null    float64
#  11  TOANLOGICPHANTICH    100 non-null    float64
#  12  GIAIQUYETVANDE       100 non-null    float64
#  13  KT                   100 non-null    object
#  14  NGAYTHI              100 non-null    object
# ...

# %%
df=df[['T5','T6','GT','DT','KV','KT','NGONNGU','TOANLOGICPHANTICH','GIAIQUYETVANDE','NGAYTHI','DINHHUONGNGHENGHIEP']]

# %%
#đổi tên
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\2879564084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
#      T5   T6 GT  DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP
# 0   7.4  6.9  F NaN  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M NaN    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M NaN    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M NaN    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M NaN  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..  ..  ...  ..      ...    ...    ...        ...         ...
# 95  7.9  6.6  F NaN    1   C     5.25   1.50   6.25  7/20/2022         Yes
# ...

# %%
#Xóa bỏ các dòng dữ liệu rỗng
df.dropna(how='all', inplace=True)
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\1146647208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='all', inplace=True)
#      T5   T6 GT  DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP
# 0   7.4  6.9  F NaN  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M NaN    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M NaN    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M NaN    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M NaN  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..  ..  ...  ..      ...    ...    ...        ...         ...
# 95  7.9  6.6  F NaN    1   C     5.25   1.50   6.25  7/20/2022         Yes
# ...

# %%
#xóa bỏ các dòng dữ liệu bị trùng
df.drop_duplicates(inplace=True)
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\3856338134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
#      T5   T6 GT  DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP
# 0   7.4  6.9  F NaN  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M NaN    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M NaN    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M NaN    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M NaN  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..  ..  ...  ..      ...    ...    ...        ...         ...
# 95  7.9  6.6  F NaN    1   C     5.25   1.50   6.25  7/20/2022         Yes
# ...

# %%
#Dùng heatmap để trực quan hóa dữ liệu thiếu
plt.figure(figsize=(10,6))
sns.heatmap(df.isna().transpose(), cmap='YlGnBu',
    cbar_kws={'label':'Dữ liệu thiếu'})
plt.savefig('missingdata.png', dpi=100)
'''
    Note: với dữ liệu bị thiếu: (1) càn xác định biến số nào bị thiếu
    (2) mức độ thiếu dữ liệu
    (3) có cần phải xư lý không

    => dựa vào biều đồ ta thấy: biến DT bị thiếu
'''
# Out:
# '\n    Note: với dữ liệu bị thiếu: (1) càn xác định biến số nào bị thiếu\n    (2) mức độ thiếu dữ liệu\n    (3) có cần phải xư lý không\n\n    => dựa vào biều đồ ta thấy: biến DT bị thiếu\n'

# %%
#Điền giá trị thiếu
df['DT'].fillna('KINH', inplace=True)
#lưu ý: với biến định tính ta có thể thay bằng giá trị yếu vị (mode)
#df['DT'].fillna(df['DT'].mode()[0], inplace=True)
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\770675315.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DT'].fillna('KINH', inplace=True)
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M  KINH    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M  KINH    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M  KINH    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..   ...  ...  ..      ...    ...    ...        ...         ...
# 95  7.9  6.6  F  KINH    1   C     5.25   1.50   6.25  7/20/2022         Yes
# ...

# %%
#Điền thiếu giá trị phần NGONNGU bằng 0 (nếu có)
df['NGONNGU'].fillna(0, inplace=True)
#Điền thiếu giá trị phần LOGIC bằng trung bình (nếu có)
df['LOGIC'].fillna(df['LOGIC'].mean(), inplace=True)
#Điền thiếu giá trị phần UNGXU bằng trung vị (nếu có)
df['UNGXU'].fillna(df['UNGXU'].median(), inplace=True)
#Lưu ý: với biến định lượng thì ta nên thay bằng trung vị
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\61719296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NGONNGU'].fillna(0, inplace=True)
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\61719296.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LOGIC'].fillna(df['LOGIC'].mean(), inplace=True)
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\61719296.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
'''
Phần 2: Kỹ thuật Feature Engineering
(thường dùng cho Machine Learning)
Nếu chỉ là xửu lý phân tích dữ liệu thì ta gọi là New Attribute

Đây là kỹ thuật tạo thêm hoặc biến đổi số liệu sẵn có thành
các biến số mới phù hợp với nghiệp vụ để phân tích

Tạo biến TBTOAN: trung bình toán lớp 12
'''
df['TBTOAN']=(df['T5']+df['T6'])/2
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\2171263857.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TBTOAN']=(df['T5']+df['T6'])/2
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M  KINH    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M  KINH    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M  KINH    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..   ...  ...  ..      ...    ...    ...        ...         ...
# ...

# %%
#Tạo biến XEPLOAI: đánh giá môn toán dựa trên df['TBToan]
df.loc[df['TBTOAN']<5.0, 'XEPLOAI']='FAIL'

df.loc[(df['TBTOAN']>=5.0) &
       (df['TBTOAN']<7.0), 'XEPLOAI']='FAIR'

df.loc[(df['TBTOAN']>=7.0) &
       (df['TBTOAN']<9.0), 'XEPLOAI']='GOOD'

df.loc[df['TBTOAN']>=9.0, 'XEPLOAI']='EXCEL'
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\724885999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['TBTOAN']<5.0, 'XEPLOAI']='FAIL'
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M  KINH    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M  KINH    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M  KINH    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..   ...  ...  ..      ...    ...    ...        ...         ...
# ...

# %%
#tìm dữ liệu theo yêu cầu - tìm loại 2NT trên KV
df[df['KV'] == '2NT']
# Out:
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# 14  8.6  8.5  F  KINH  2NT   A     3.50   4.50   6.50  12/7/2018          No
# 23  5.3  6.1  M  KINH  2NT   C     6.75   5.25   5.00  6/13/2019          No
# 27  5.8  5.6  F  KINH  2NT   C     5.25   5.00   3.50  6/13/2019         Yes
# 28  8.3  8.4  M  KINH  2NT   A     3.25   5.25   3.75  6/13/2019          No
# 34  6.4  7.0  M  KINH  2NT   A     2.50   4.50   4.50  6/13/2019          No
# 44  7.8  7.8  F  KINH  2NT   A     3.75   4.00   4.00  8/15/2020         Yes
# 49  7.5  7.6  F  KINH  2NT  A1     3.25   4.50   4.00  8/15/2020         Yes
# 52  7.4  5.9  F  KINH  2NT  D1     3.75   3.50   4.50  8/15/2020          No
# 55  9.5  9.5  F  KINH  2NT  A1     4.25   4.75   3.25  8/15/2020          No
# ...

# %%
'''
Tạo biến nhóm khối thi: NHOMKT thõa mãn 
A1: G1
C: G3
D1: G3
A: G1
B: G2
'''
dict_map={
    'A1':'G1','C':'G3','D1':'G3','A':'G1','B':'G2'
}
df['NHOMKT']=df['KT'].map(dict_map)
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\2112803021.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NHOMKT']=df['KT'].map(dict_map)
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M  KINH    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M  KINH    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M  KINH    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..   ...  ...  ..      ...    ...    ...        ...         ...
# ...

# %%
'''
#Tạo bién số điểm cộng: CONG
Nếu khối thi thuộc nhóm G1, G2 và TBTOAN >= 5.0 thì 1.0 
Ngược lại thì 0.0
'''
def fplus(x,y):
    if (x=='G1' or x=='G2') and (y >= 5.0):
        return 1.0
    else:
        return 0.0

df['CONG']=list(map(fplus,df['NHOMKT'], df['TBTOAN']))
df
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\834528882.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CONG']=list(map(fplus,df['NHOMKT'], df['TBTOAN']))
#      T5   T6 GT    DT   KV  KT  NGONNGU  LOGIC  UNGXU    NGAYTHI HUONGNGHIEP  \
# 0   7.4  6.9  F  KINH  2NT  A1     3.25   3.25   4.50  12/7/2018          No
# 1   3.0  4.0  M  KINH    1   C     6.00   4.00   3.50  12/7/2018         Yes
# 2   4.8  5.7  M  KINH    1   C     5.00   6.75   4.00  12/7/2018          No
# 3   6.1  7.4  M  KINH    1  D1     4.25   4.25   5.25  12/7/2018          No
# 4   6.8  8.0  M  KINH  2NT   A     4.25   4.50   5.00  12/7/2018          No
# ..  ...  ... ..   ...  ...  ..      ...    ...    ...        ...         ...
# ...

# %%
'''
Phần 3: trực quan góa dữ liệu
Đê trực quan số liệu ta cần lưu ý: mục đích, sự phối hợp giữa các loại biến để chọn lựa
biểu đồ phù hợ[ đi kèm số liệu trực quan
Định tính: bar, pie,
Định lượng: scatter ,line, histogram, box-plot
'''
# Out:
# '\nPhần 3: trực quan góa dữ liệu\nĐê trực quan số liệu ta cần lưu ý: mục đích, sự phối hợp giữa các loại biến để chọn lựa\nbiểu đồ phù hợ[ đi kèm số liệu trực quan\nĐịnh tính: bar, pie,\nĐịnh lượng: scatter ,line, histogram, box-plot\n'

# %%
'''
Hãy trực quan số lượng học sinh theo giới tính
'''

sns.countplot(x='GT', data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
#sinh viên lưu ý:
các biến dùng để phân nhóm, gom nhóm thông thường là biến đinh tính và nằm ở các thang đo mức 1,2,3,4 tương
ứng định danh, phân loại, thức bậc và khoảng
'''
# Out:
# '\n#sinh viên lưu ý:\ncác biến dùng để phân nhóm, gom nhóm thông thường là biến đinh tính và nằm ở các thang đo mức 1,2,3,4 tương\nứng định danh, phân loại, thức bậc và khoảng\n'

# %%
'''
sinh viên tự làm tương tư cho các cột KV, DT, KT
--> Dựa trên biểu đồ DT cho biết tại sao ta không phân tích theo phân nhóm DT
'''
sns.countplot(x='KV', data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.countplot(x='DT', data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.countplot(x='KT', data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#
sns.countplot(x='KV', hue='KT',data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.barplot(x='GT', y='NGONNGU', data=df, ci=None)
plt
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\755794048.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='GT', y='NGONNGU', data=df, ci=None)
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
so sánh sai số trên NGONNGU theo nhóm GT theo KT
'''
sns.barplot(x='GT', y='NGONNGU',hue='KT', data=df, ci=None)
plt
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\2689887792.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='GT', y='NGONNGU',hue='KT', data=df, ci=None)
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
so sánh điểm cao nhất của NGONNGU theo nhóm GT trong KT
lưu ý: không để estimator thì mặc định là mean
'''

sns.barplot(x='GT', y='NGONNGU',hue='KT', data=df, ci=None, estimator=max)
plt
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\215923101.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='GT', y='NGONNGU',hue='KT', data=df, ci=None, estimator=max)
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import numpy as np
#khi có nhiều nhóm (>2) thì ta cần dùng hàm của tổng hợp thông qua thư viện của numpy

sns.barplot(x='KV', y='NGONNGU',hue='KT', data=df, ci=None, estimator=np.max)
plt
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\3378894768.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='KV', y='NGONNGU',hue='KT', data=df, ci=None, estimator=np.max)
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
sinh viên lưu ý:
- với biến định tính thì ta chỉ có một hàm tổng là hàm COUNT, MODE (xuất hiện nhiều nhất)
- với định lượng thi ta có thể sử dụng các hàm tổng hợp như: COUNT, MAX, MIN, MEDIAN, SUM, STD
'''
# Out:
# '\nsinh viên lưu ý:\n- với biến định tính thì ta chỉ có một hàm tổng là hàm COUNT, MODE (xuất hiện nhiều nhất)\n- với định lượng thi ta có thể sử dụng các hàm tổng hợp như: COUNT, MAX, MIN, MEDIAN, SUM, STD\n'

# %%
'''
Biểu đồ PTE
Mục đích: Trực quan dữ liệu theo nhóm tỉ lệ
'''

gb=df.groupby(['KT'])['KT'].agg(['count'])

labels=gb.index
data=list(gb['count'])

colors=sns.color_palette('pastel') # Tạo bảng màu

plt.pie(data, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
gb=df.groupby(['KV'])['KV'].agg(['count'])

labels=gb.index
data=list(gb['count'])

colors=sns.color_palette('pastel') # Tạo bảng màu

plt.pie(data, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
gb=df.groupby(['KV'])['CONG'].agg(['sum'])

labels=gb.index
data=list(gb['sum'])

colors=sns.color_palette('pastel') # Tạo bảng màu

plt.pie(data, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
Biểu đồ line thường dùng để tổng hợp dữ liệu theo trục "thời gian" hoặc "có thứ tự"

ví dụ: Tổng hợp trung bình điểm cộng theo các năm thi
'''

sns.lineplot(x='NGAYTHI', y='CONG', data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
Tổng quan dữ liệu tổng điểm CONG dựa theo năm bằng biểu đồ line
'''

sns.lineplot(x='NGAYTHI', y='CONG', data=df, estimator=sum)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.lineplot(x='NGAYTHI', y='CONG',hue='GT', data=df, estimator=sum)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
Phần 4: phân tích định lượng 
Phân tích định lượng lấy trọng tâm là các biến định lượng
#mean: giá trị trung bình là giá trị đại biểu cho 1 tập dữ liệu số, nó thể hiện giá trị kỳ vọng cho tập dữ liệu
#độ lệch chuẩn bằng căn của giá  trị phương sai. độ lệch chuẩn và phương sai thể hiện mức độ biến thiên, biến động, sự đa dạng của tập dữ liệu số. độ lệch chuẩn càng cao
 thì tập dữ liệu biến động càng mạnh và ngược lại
'''

#Bước 1:
import pandas as pd
import matplotlib as plt
import seaborn as sns
from scipy import stats
df=pd.read_csv('dulieuxettuyendaihoc.csv')

#mô tả thống kê
df['NGONNGU'].describe()
# Out:
# count    100.000000
# mean       3.740000
# std        1.424408
# min        1.000000
# 25%        2.500000
# 50%        3.625000
# 75%        4.750000
# max        7.000000
# Name: NGONNGU, dtype: float64

# %%
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)
df
# Out:
#        MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  LOGIC  UNGXU  \
# 0     SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25   3.25   4.50
# 1     SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00   4.00   3.50
# 2     SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00   6.75   4.00
# 3     SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25   4.25   5.25
# 4     SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25   4.50   5.00
# ..      ...  ...  ...  ...  ...  ...  ... ..  ..  ...      ...    ...    ...
# 95   SV0096  8.6  8.9  7.7  6.7  7.9  6.6  F NaN    1     5.25   1.50   6.25
# 96   SV0097  3.7  4.1  3.1  3.4  5.5  5.7  F NaN    1     5.25   3.75   4.75
# 97   SV0098  8.8  9.5  9.5  8.5  9.0  8.5  M NaN  2NT     7.00   8.00   4.00
# 98   SV0099  2.7  2.8  6.2  5.2  4.1  4.3  M NaN    1     5.00   3.50   5.50
# 99  SV00100  4.1  4.4  6.0  4.3  5.6  5.1  M NaN  2NT     5.25   2.50   4.25
#
#     KT    NGAYTHI HUONGNGHIEP
# ...

# %%
#Giải thích ý nghĩa các đại lượng
'''
#mean: giá trị tb là giá trị đại biểu cho 1 tập dữ liẹu số, nó thể hiện giá trị kỳ vọng cho tập dữ liệu

#std: độ lệch chuẩn bằng căn của giá  trị phương sai. đlc và phương sai thể hiện mứuc đọo biến thiên, biến động, sự đa dạng của tập dữ liệu số. DLC càng cao
 thì tập dữ liệu biến động mạnh và ngược lại

 #25%: Q1 có 25% giá trị nhỏ hơn 
 #50%: Q2(trung vị Median) cho biết 50% giá trị nhỏ hơn và 50% có giá trị lớn hơn
 #75%: Q3 có 25% giá trị lớn hơn
 #IQR: 25%-->75%: thể hiện mức bình thường 
    IQR= Q3 - Q1
 #VD: độ dài [2.5 , 4.75] = 2.25
'''
# Out:
# '\n#mean: giá trị tb là giá trị đại biểu cho 1 tập dữ liẹu số, nó thể hiện giá trị kỳ vọng cho tập dữ liệu\n\n#std: độ lệch chuẩn bằng căn của giá  trị phương sai. đlc và phương sai thể hiện mứuc đọo biến thiên, biến động, sự đa dạng của tập dữ liệu số. DLC càng cao\n thì tập dữ liệu biến động mạnh và ngược lại\n\n #25%: Q1 có 25% giá trị nhỏ hơn \n #50%: Q2(trung vị Median) cho biết 50% giá trị nhỏ hơn và 50% có giá trị lớn hơn\n #75%: Q3 có 25% giá trị lớn hơn\n #IQR: 25%-->75%: thể hiện mức bình thường \n    IQR= Q3 - Q1\n #VD: độ dài [2.5 , 4.75] = 2.25\n'

# %%
'''
    Nếu giá trị mean lệch ít thì so sánh trực tiếp STD, nếu giá trị mean
lệch nhiều thì áp dụng CV để so sánh:
    CV=dlc/xichma (cv=std/mean)

Hệ số biến thiên cho phép so sánh mức độ biến thiên giữa các tập dữ liệu 
có đơn vị khác nhau hoặc có giá trị trung bình khác nhau. Nếu hệ số biến 
thiên cao, tức là dữ liệu có mức độ biến động lớn hơn so với giá trị trung 
bình của nó. Ngược lại, nếu hệ số biến thiên thấp, tức là dữ liệu có mức độ 
biến động nhỏ hơn so với giá trị trung bình của nó.
'''
df[['NGONNGU','LOGIC','UNGXU']].describe()
# Out:
#           NGONNGU       LOGIC       UNGXU
# count  100.000000  100.000000  100.000000
# mean     3.740000    4.255000    4.875000
# std      1.424408    1.060053    1.041136
# min      1.000000    1.500000    2.750000
# 25%      2.500000    3.500000    4.250000
# 50%      3.625000    4.125000    4.750000
# 75%      4.750000    4.750000    5.500000
# max      7.000000    8.000000    8.000000

# %%
#so sánh 3 cột 
cv=df[['NGONNGU','LOGIC','UNGXU']].std()/df[['NGONNGU','LOGIC','UNGXU']].mean()
cv
# Out:
# NGONNGU    0.380858
# LOGIC      0.249131
# UNGXU      0.213566
# dtype: float64

# %%
df.groupby('GT')['NGONNGU'].describe()
# Out:
#     count      mean       std   min     25%   50%  75%  max
# GT
# F    48.0  3.854167  1.348594  1.25  3.1875  3.75  5.0  7.0
# M    52.0  3.634615  1.496288  1.00  2.4375  3.50  4.5  7.0

# %%
df.groupby('GT')[['NGONNGU', 'UNGXU','LOGIC']].describe()
#Hỏi: so sánh các biến số
# Out:
#    NGONNGU                                                   UNGXU            \
#      count      mean       std   min     25%   50%  75%  max count      mean
# GT
# F     48.0  3.854167  1.348594  1.25  3.1875  3.75  5.0  7.0  48.0  4.906250
# M     52.0  3.634615  1.496288  1.00  2.4375  3.50  4.5  7.0  52.0  4.846154
#
#     ...            LOGIC
#     ...  75%   max count      mean       std  min   25%  50%  75%   max
# GT  ...
# F   ...  5.5  7.25  48.0  4.046875  1.021909  1.5  3.50  4.0  4.5  6.75
# M   ...  5.5  8.00  52.0  4.447115  1.067956  2.5  3.75  4.5  5.0  8.00
#
# [2 rows x 24 columns]

# %%
'''
Histogram 
'''
df['NGONNGU'].hist()
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
# Hướng dẫn về bins trong histogram
#Lưu ý: khi số lượng bins khác nnhau sẽ dẫn đến hình dáng của histogram
df['NGONNGU'].hist(bins=14)
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
#Nâng cao hơn histogram, thì ta khám phá dạng phân phối xác xuất làm
# mịn với phân phối xác xuất
sns.displot(df, x='NGONNGU', kind='kde')
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
sns.displot(data=df[['NGONNGU','LOGIC', 'UNGXU']],kind='kde')
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
sns.displot(df, x='NGONNGU', hue='GT', kind='kde')
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
'''
Đây là biểu dồ qiuan tọng trong việc phân tích dữ liệu định lượng
biểu đồ này cung cấp các thông tin quan trọng như:
    1. Q1: tứ phân vị 25%
    2. Q2: tứ phân vị 50% (median)
    3. Q3: tứ phân vị 75%
    4. Độ lớn IQR= |Q3-Q1|
    5. Lower bound= Q1 - 1.5*IQR
    6. Upper bound= Q3 + 1.5*IQR
    7. Các ngoại biên, bất thường (outlier) cần xử lý trong dữ liệu 
    Outlier: là các điểm dữ liệu khác biệt quá nhiều so với đa số
    Hướng dẫn
        + Tính khoảng nghi ngờ chứa outliers
        + Tính khoảng chắc chắn chưua outliers


#Lưu ý thứ tự: ngoại biên - nghi ngờ ngoại biên - lowerBoud - IQR - uperBound - nghi ngờ ngoại biên - ngoại biên
'''
sns.boxplot(data=df['LOGIC'], orient="h")
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
'''
IQR=1.25
Lowerbound= Q1 - 1.5*IQR= 3.5 - (1.5*1.25)= 1.625
Upperbound= Q3 + 1.5*IQR= 4.75 + 1.5*1.25= 6.625
Nghi ngờ (L): Q1 - 3*IQR= 3.5 - 3*IQR = 3.5 - 3.75 = -0.25
Ngoại biên (L): Q1 - 4.5*IQR= 3.5 - 4.5*1.25= 3.5 - 5.625 = -2.125
Nghi ngờ (U): Q3 + 3*IQR= 4.75 + 3.75 = 8.5
Ngoại biên (U): Q3 + 4.5*IQR= 4.75 + 5.625 =10.375
'''
df[['LOGIC']].describe()
# Out:
#             LOGIC
# count  100.000000
# mean     4.255000
# std      1.060053
# min      1.500000
# 25%      3.500000
# 50%      4.125000
# 75%      4.750000
# max      8.000000

# %%
sns.boxplot(x='NGONNGU', y='KT', data=df, orient='h')
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
sns.boxplot(data=df[['NGONNGU','LOGIC','UNGXU']], orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x='KT', y='NGONNGU', hue='GT', data=df)
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
'''
Skewness = độ xiên, độ lớn ( trị tuyệt đối ) cho biết mức độ dữ liệu lệch nhiều hay ít so với đường cong phân phối chuẩn.
Cho biết xác xuất đc phân bổ lệch về phía nào nhiều
Trị tuyệt đối gtri càng lớn thì dlieu pphoi nghiêng càng nhiều ( lệch )
Diễn giải Skewness:
- Skewness > 0 tức là mean > median: ta hội là Positive Skewness hay lệch phải, tức là gía trị
ngoại biên ( outliers ) nhận gía trị lớn sẽ đẩy gía trị trung bình về cuối
- Skewness < 0 tức là mean < median: ta hội là Positive Skewness hay lệch trái, tức là gía trị
ngoại biên ( outliers ) nhận gía trị nhỏ sẽ đẩy gía trị trung bình về đầu
- Skewness = 0 tức là mean = median = mode: Phân phối không lệch còn đgl phân phối đối xứng 
'''
#skew: kết quả dương lệch phải, âm lệch trái
df['NGONNGU'].skew()
# Out:
# 0.33322084231625376

# %%
'''
note: khi phân tích dữ liệu với các phương pháp có liên quan phân phối chuẩn
- Nếu dữ liệu quá lệch so với phân phối chuẩn thì ta cần điều chỉnh bằng các hàm transform cho bớt lệch 
đặc biệt là phân tích hồi quy
'''
df[['NGONNGU','LOGIC','UNGXU']].skew()
# Out:
# NGONNGU    0.333221
# LOGIC      0.472551
# UNGXU      0.607063
# dtype: float64

# %%
'''
Kurtosis: độ nhọn, trị tuyệt đối cho biết mức độ nhọn của phân phối

Độ lớn của kurtosis: 
+ Càng gần 3 thì fit
+ Dưới 3 thì fat
+ Trên 3 thì thin

Thông thường để đánh giá hình dáng độ nhọn ta dùng đại lượng 
excess kurtosis = kurtosis - 3
+ Nếu excess > 0 thì thin
+ Nếu excess = 0 thì fit
+ Nếu excess < 0 thì fat

Trong pandass sử dụng Fisher's kurtosis tức là đã 
chuẩn hóa gía trị về excess kurtosis theo mean = 0

Trị tuyệt đối excess kurtoris càng cao thì mức độ thin, fat càng lớn
lưu ý: với phân phối chuẩn thì excess kurtosis =0, skewness=0

Câu hỏi: biến NGONNGU có độ nhọn như thế nào ?
Trả lời: fat
'''
df[['NGONNGU']].kurtosis()
# Out:
# NGONNGU   -0.517004
# dtype: float64

# %%
df[['NGONNGU','LOGIC','UNGXU']].kurtosis()
# Out:
# NGONNGU   -0.517004
# LOGIC      1.372439
# UNGXU      0.442173
# dtype: float64

# %%
stats.probplot(df['NGONNGU'], plot=sns.mpl.pyplot)
plt
# Out:
# <module 'matplotlib' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
df=pd.read_csv('dulieuxettuyendaihoc.csv')
df.head(10)
# Out:
#      MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0   SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1   SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2   SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3   SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4   SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# 5   SV006  9.3  9.6  7.1  8.5  8.5  7.8  M NaN    1     1.50
# 6   SV007  2.8  4.4  4.6  4.7  5.4  5.3  F NaN    2     6.50
# 7   SV008  8.3  6.7  8.6  8.3  8.5  8.3  F NaN    2     3.75
# 8   SV009  6.5  7.3  6.4  8.1  7.7  7.7  F NaN    1     3.50
# 9  SV0010  7.3  8.0  6.5  5.5  7.5  6.9  F NaN    1     4.00
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# ...

# %%
'''
Phân tích sự tác dộng (ảnh hưởng) qua lại giữa 2 biến định lượng
Phương pháp 1: Hiệp phương sai: co-variance (covariance)
    giá trị co_variance > 0 thì 2 biến có tương quan thuận (đồng biến)
    giá trị có .........< 0........................nghịch (nghịch biến)
    độ lớn (trị tuyệt đối) càng lớn thì mức độ quan hệ (tương quan) càng chặt chẽ

    
    Ma trận hiệp phương sai: co-variance
    
'''
df[['T5','T6']].cov()
# Out:
#           T5        T6
# T5  2.184658  1.568961
# T6  1.568961  1.858314

# %%
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)

# %%
#so sánh mứuc độ tương quan giữa T5 so với LOHGIC và T6 so với LOGIC
#Trả lời: T6
df[['T5','T6','LOGIC']].cov()
# Out:
#              T5        T6     LOGIC
# T5     2.184658  1.568961  0.289308
# T6     1.568961  1.858314  0.435672
# LOGIC  0.289308  0.435672  1.123712

# %%
'''
Với phương pháp so sánh tương quan bằng co-variance (covariance) thì ta không đo lường được cường độ tương quan giữa
2 biến định lượng.

pearson Corelation: tương quan tuyến tính
r nằm trong khoảng [-1:1]
r=0: không tương quan
r<0: tương quan nghịch
r>0: tuong quan thuận
|r|: càng gần 1 thì tương quan càng cao
|r|:< 0.5 thì tương quan thấp
    [0.5, 0.65]: khá
    [0.65, 0.75]: tốt
    [0.75, 0.9]: rất tốt
    >0.9: hoàn hảo
'''
df[['T5','T6']].corr()
#trả lời: r=0.77 =>> rất tốt
# Out:
#           T5        T6
# T5  1.000000  0.778683
# T6  0.778683  1.000000

# %%
'''
Giải thích 
khám phá tương quan tuyến tính của 2 bién định lượng
thông qua biểu đồ phân tán (scatter)
'''
sns.lmplot(data=df, x='T5', y='T6', fit_reg=True)
plt
#Nếu r càng gần 1 thì các chấm xanh sẽ càng gần đường thẳng
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#cho biết mức độ tương quan giữa T6 và ứung xử
df[['T6','UNGXU']].corr()
#trả lời: r=0.04 sấp sĩ 0 nên không tương quan
# Out:
#              T6     UNGXU
# T6     1.000000  0.045638
# UNGXU  0.045638  1.000000

# %%
sns.lmplot(data=df, x='T6', y='UNGXU', fit_reg=True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#so sánh mức độ tương quan của T5,T6,NGONNGU,LOGIC,UNGXU
df[['T5','T6','NGONNGU','LOGIC','UNGXU']].corr()
# Out:
#                T5        T6   NGONNGU     LOGIC     UNGXU
# T5       1.000000  0.778683  0.019512  0.184647  0.026830
# T6       0.778683  1.000000 -0.033360  0.301490  0.045638
# NGONNGU  0.019512 -0.033360  1.000000  0.035154  0.018731
# LOGIC    0.184647  0.301490  0.035154  1.000000 -0.091523
# UNGXU    0.026830  0.045638  0.018731 -0.091523  1.000000

# %%
#tương quan bằng biều đồ heatmap
sns.heatmap(df[['T5','T6','NGONNGU','LOGIC','UNGXU']].corr(), vmax=1.0, square=False).xaxis.tick_top()

# %%
#Biểu đồ tổng hợp khám phá định lượng
sns.pairplot(df[['T5','T6','NGONNGU','LOGIC','UNGXU']], diag_kind='kde', kind='reg')
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
'''
Trực quan tương quan tuyến tính theo nhóm (định tính) giữa 2 biến dịnh lượng
'''
sns.lmplot(data=df, x='T5', y='T6', hue='GT', fit_reg=True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hakate\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#PHÂN TÍCH HỒI QUY TUYẾN TÍNH

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest as ztest
from scipy.stats.stats import pearsonr
from scipy.stats import chi2_contingency
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\4058323872.py:7: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
df=pd.read_csv('dulieuxettuyendaihoc.csv')
df.head(10)
# Out:
#      MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0   SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1   SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2   SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3   SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4   SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# 5   SV006  9.3  9.6  7.1  8.5  8.5  7.8  M NaN    1     1.50
# 6   SV007  2.8  4.4  4.6  4.7  5.4  5.3  F NaN    2     6.50
# 7   SV008  8.3  6.7  8.6  8.3  8.5  8.3  F NaN    2     3.75
# 8   SV009  6.5  7.3  6.4  8.1  7.7  7.7  F NaN    1     3.50
# 9  SV0010  7.3  8.0  6.5  5.5  7.5  6.9  F NaN    1     4.00
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# ...

# %%
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)

# %%
'''
Phân tích hồi quy tuyến tính
mục đích: phân tích tác động hay ảnh hưởng giữa các yếu tố đến mục tiêu
thường dùng cho các biến (yếu tố) định lượng
thường vẽ biểu đồ scatter để khám phá mỗi tương quan tuyến tính trước kho khám
phá quan hệ hồi quy tuyến tính


PHƯƠNG PHÁP:
    1. Xác định biến độc lập và biến phụ thuộc (biến mục tiêu)
    2. Ghiu ra phương trình hòi quy tuyến tính tổng quát y=f(x)
    3. Chạy dữ liệu mô hình
    4. Đọc các giá trị quan trọng và kết luận
    5. Dự báo giá trị biến phụ thuộc khi biết trước giá trị biến độc lập
'''
# Out:
# '\nPhân tích hồi quy tuyến tính\nmục đích: phân tích tác động hay ảnh hưởng giữa các yếu tố đến mục tiêu\nthường dùng cho các biến (yếu tố) định lượng\nthường vẽ biểu đồ scatter để khám phá mỗi tương quan tuyến tính trước kho khám\nphá quan hệ hồi quy tuyến tính\n\n\nPHƯƠNG PHÁP:\n    1. Xác định biến độc lập và biến phụ thuộc (biến mục tiêu)\n    2. Ghiu ra phương trình hòi quy tuyến tính tổng quát y=f(x)\n    3. Chạy dữ liệu mô hình\n    4. Đọc các giá trị quan trọng và kết luận\n    5. Dự báo giá trị biến phụ thuộc khi biết trước giá trị biến độc lập\n'

# %%
#Hãy cho biết sự ảnh hưởng của điểm hk1 năm lớp 12 đến điểm hk2 năm lớp 12
'''
        b1: độc lập T5
            phụ thuộc YT6
        b2:T6=f(T5)
             =A0 + A1*T5 + epsilong
             Note: A0: interception
                   A1: coficiput
                   epsilong: phần dư
        b3: chạy mô hình
        b4: đọc và hiểu kết quả
 '''
#adding a constant: thêm 1 hằng số
X_with_constant = sm.add_constant(df[["T5"]].values)

y=df[['T6']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X_with_constant).fit()

#result of statsmodels: 
print (result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     151.0
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           1.48e-21
# Time:                        10:27:56   Log-Likelihood:                -125.76
# No. Observations:                 100   AIC:                             255.5
# Df Residuals:                      98   BIC:                             260.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1130      0.402      5.257      0.000       1.315       2.911
# ...

# %%
'''
b4:
Giải thích bảng:
    Adj. R-squared:                         0.602: căn cứ vào bằng T5 có 60% ảnh hưởng đến T6
    Prob (F-statistic)=p=value:             1.48e-21
    const                                   2.1130
    x1                  P>|t|               0.000: có ý nghĩa thống kê 
    x1=T5
    
    
    =>T6= 2.113 + 0.7182 * T5
    '''
# Out:
# '\nb4:\nGiải thích bảng:\n    Adj. R-squared:                         0.602: căn cứ vào bằng T5 có 60% ảnh hưởng đến T6\n    Prob (F-statistic)=p=value:             1.48e-21\n    const                                   2.1130\n    x1                  P>|t|               0.000: có ý nghĩa thống kê \n    x1=T5\n    \n    \n    =>T6= 2.113 + 0.7182 * T5\n    '

# %%
'''
b5: giả sữ T5=7.5 
    hãy dự báo T6=?
    =>T6= 7.499
'''
# Out:
# '\nb5: giả sữ T5=7.5 \n    hãy dự báo T6=?\n    =>T6= 7.499\n'

# %%
#vd: t6 và LOGIC
#adding a constant: thêm 1 hằng số
X_with_constant = sm.add_constant(df[["T6"]].values)

y=df[['LOGIC']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X_with_constant).fit()

#result of statsmodels: 
print (result.summary())
'''
Adj. R-squared:                  0.082: căn cứ vào T6 chỉ giải thích đc 8% điểm Logic
Prob (F-statistic):              0.00230 <0.05 => có ý nghĩa thống kê
LOGIC= 2.6287 + 0.2344 *T6


vd: giả sữ T6: 7.0
=>>LOGIC=2.6287 +0.2344 *T6= 4.2695
'''
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     9.798
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):            0.00230
# Time:                        10:27:56   Log-Likelihood:                -142.46
# No. Observations:                 100   AIC:                             288.9
# Df Residuals:                      98   BIC:                             294.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6287      0.529      4.965      0.000       1.578       3.679
# ...

# %%
#hãy phân tích sự ảnh hưởng của điểm Toán hk1, hk2 năm lớp 12 đến điểm LOGIC
X_with_constant = sm.add_constant(df[["T5","T6"]].values)

y=df[['LOGIC']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X_with_constant).fit()

#result of statsmodels: 
print (result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.226
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):            0.00699
# Time:                        10:27:56   Log-Likelihood:                -142.11
# No. Observations:                 100   AIC:                             290.2
# Df Residuals:                      97   BIC:                             298.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7072      0.539      5.026      0.000       1.638       3.776
# ...

# %%
#hãy phân tích sự ảnh hưởng của điểm Toán hk1, hk2 năm lớp 12 đến điểm NGONNGU
X_with_constant = sm.add_constant(df[["T5","T6"]].values)

y=df[['NGONNGU']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X_with_constant).fit()

#result of statsmodels: 
print (result.summary())
'''
Adj. R-squared:                 -0.014 lấy GTTD: 0.014
...
'''
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3109
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):              0.734
# Time:                        10:27:56   Log-Likelihood:                -176.45
# No. Observations:                 100   AIC:                             358.9
# Df Residuals:                      97   BIC:                             366.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8860      0.759      5.117      0.000       2.379       5.393
# ...

# %%
'''
Đánh giá mức độ tác động giữa các yếu tố của một đói tượng bằng
phân tích hồi quy tuyến tính
'''
#Hãy cho biết mức độ tác động của T5, T6 đến điểm LOGIC
#adding a constant
X= df[["T5","T6"]].values

y=df[['LOGIC']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X).fit()

#result of statsmodels: 
print (result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              694.9
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):                    1.30e-58
# Time:                        10:27:56   Log-Likelihood:                         -153.68
# No. Observations:                 100   AIC:                                      311.4
# Df Residuals:                      98   BIC:                                      316.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#hãy phân tích sự ảnh hưởng của điểm Toán hk1, hk2 năm lớp 12 đến điểm NGONNGU
X_with_constant = sm.add_constant(df[["T5","T6"]].values)

y=df[['NGONNGU']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X_with_constant).fit()

#result of statsmodels: 
print (result.summary())
'''
Adj. R-squared:                 -0.014 lấy GTTD: 0.014
...
'''
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3109
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):              0.734
# Time:                        10:27:56   Log-Likelihood:                -176.45
# No. Observations:                 100   AIC:                             358.9
# Df Residuals:                      97   BIC:                             366.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8860      0.759      5.117      0.000       2.379       5.393
# ...

# %%
'''
Đánh giá mức độ tác động giữa các yếu tố của một đói tượng bằng
phân tích hồi quy tuyến tính
'''
#Hãy cho biết mức độ tác động của T5, T6 đến điểm LOGIC
#adding a constant
X= df[["T5","T6"]].values

y=df[['LOGIC']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X).fit()

#result of statsmodels: 
print (result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              694.9
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):                    1.30e-58
# Time:                        10:27:56   Log-Likelihood:                         -153.68
# No. Observations:                 100   AIC:                                      311.4
# Df Residuals:                      98   BIC:                                      316.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#Hãy cho biết mức độ tác động của T5, T6 đến điểm UNGXU
#adding a constant
X= df[["T5","T6"]].values

y=df[['UNGXU']].values

#perfoming the regression: thực hiện hồi quy
result=sm.OLS(y, X).fit()

#result of statsmodels: 
print (result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.926
# Model:                            OLS   Adj. R-squared (uncentered):              0.924
# Method:                 Least Squares   F-statistic:                              612.1
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):                    4.24e-56
# Time:                        10:27:56   Log-Likelihood:                         -172.41
# No. Observations:                 100   AIC:                                      348.8
# Df Residuals:                      98   BIC:                                      354.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
'''
giải thích
'''
# Out:
# '\ngiải thích\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest as ztest
from scipy.stats.stats import pearsonr
from scipy.stats import chi2_contingency
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# C:\Users\Hakate\AppData\Local\Temp\ipykernel_5956\4058323872.py:7: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
df=pd.read_csv('dulieuxettuyendaihoc.csv')
df.head(10)
# Out:
#      MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0   SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1   SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2   SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3   SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4   SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
# 5   SV006  9.3  9.6  7.1  8.5  8.5  7.8  M NaN    1     1.50
# 6   SV007  2.8  4.4  4.6  4.7  5.4  5.3  F NaN    2     6.50
# 7   SV008  8.3  6.7  8.6  8.3  8.5  8.3  F NaN    2     3.75
# 8   SV009  6.5  7.3  6.4  8.1  7.7  7.7  F NaN    1     3.50
# 9  SV0010  7.3  8.0  6.5  5.5  7.5  6.9  F NaN    1     4.00
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# ...

# %%
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',
                   'GIAIQUYETVANDE':'UNGXU',
                   'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'}, 
                   inplace=True)

# %%
'''
Phân tích suy diễn (ìnerrential statistics)
lý do tạo sai cần suy diễn: kết luạn dựa trên dữ liệu sample (mẫu),
nhưng kết luận thì được hiểu là áp dụng cho tổng thể
    Câu hỏi đặt ra: kết luận trên mẫu đso có phù hợp với tổng thể hay không

Khi phân tích suy diễn cần lưu ý:
    1. Xác định giả thuyết H0
    2. Các giả định hay các điều kiện về dữ liệu và môi trường để áp dụng kiểm định
        - Lưu ý vè giả địnnh phân phối của biến số: Normal, Student, Poison, Chi-square,....

    3. Thiết lập mứuc tin cậy và sai lầm (alpha): 90%-10%, 95%-5% và 99%-1%
    4. Quy tắc suy diễn:
        4.1 Nếu p-value < alpha: bác bỏ giả thuyết H0
        4.2 nếu ........>......: chấp nhật giả thuyết H0
    5.Kết luận của suy diễn chỉ cho chúng ta biết là có đủ dữ liệu để kết luận cho tổng thể hay không (còn gọi là ý nghĩa thống kê)
'''


'''
Phục vụ 3 bài toán chính sau:
    - Khám phá dữ liệu tương tác qua lại định tính - định tính
    - ...................................định tính - định lượng
    - ...................................định lượng - định lượng
'''
# Out:
# '\nPhục vụ 3 bài toán chính sau:\n    - Khám phá dữ liệu tương tác qua lại định tính - định tính\n    - ...................................định tính - định lượng\n    - ...................................định lượng - định lượng\n'

# %%
'''
ONE SAMPLE T-TEST
Mục đích: kiểm tra 
'''
# Out:
# '\nONE SAMPLE T-TEST\nMục đích: kiểm tra \n'

# %%
#Câu 1: kiểm tra xem trung bình điểm LOGIC của thí sinh khối C có bằng 4 hay không
#kiểm tra xem n<30 hay không? như bên dưới ta đếm được n=14 nên lấy
dfkhoic=df.loc[df['KT']=='C']
dfkhoic['LOGIC']
# Out:
# 1     4.00
# 2     6.75
# 6     6.75
# 22    3.50
# 23    5.25
# 24    2.25
# 25    2.00
# 26    4.50
# 27    5.00
# 95    1.50
# 96    3.75
# 97    8.00
# 98    3.50
# 99    2.50
# Name: LOGIC, dtype: float64

# %%
#Với one sample T-test thì giả thuyế H0: muy=4.0
#mặc định mức tin cậy là 95% và mức sai lầm là 5%
stats.ttest_1samp(dfkhoic['LOGIC'], popmean=4.0)
#kết luận: đủ điều kiện để chấp nhạn giả thuyết H0, điểm trung bình của môn thi LOGIC bằng 4, hay
#nói cách khác chấp nhận H0 ở mức sai lầm 5%
# Out:
# TtestResult(statistic=0.44599723713991907, pvalue=0.6629370899710998, df=13)

# %%
#sinh viên kiểm tra  xem điểm trung bình của môn thi UNGXU của khối thi C có bằng 5.0 hay không?
#đếm các giá trị nếu dưới 30 thì tính tiếp (n<30)
dfkhoic=df.loc[df['KT']=='C']
dfkhoic['UNGXU']
# Out:
# 1     3.50
# 2     4.00
# 6     5.25
# 22    6.00
# 23    5.00
# 24    5.25
# 25    5.50
# 26    4.75
# 27    3.50
# 95    6.25
# 96    4.75
# 97    4.00
# 98    5.50
# 99    4.25
# Name: UNGXU, dtype: float64

# %%
stats.ttest_1samp(dfkhoic['UNGXU'], popmean=5.0)
#=>>> chấp nhận H0
#kết luận: đủ điều kiện để chấp nhạn giả thuyết H0, điểm trung bình của môn thi UNGXU bằng 5, hay
#nói cách khác chấp nhận H0 ở mức sai lầm 5%
# Out:
# TtestResult(statistic=-0.7645471693105148, pvalue=0.4581953822944209, df=13)

# %%
#Câu 2: hãy kiểm tra xem trung bình điểm thi LOGIC và trung bình điểm thi UNGXU của thí sinh khối C có bằng nhau hay không?
#H0: mean_LOGIC - mean_UNGXU =0

dfkhoic=df.loc[df['KT']=='C']
stats.ttest_ind(dfkhoic['LOGIC'], dfkhoic['UNGXU'], equal_var=True)
# Out:
# Ttest_indResult(statistic=-1.0329196014245297, pvalue=0.3111543826061086)

# %%
'''
Kết luận: do alpla = 0.05 và p-value = 0.3111 suy ra đủ dữ liệu để nói rằng triung bình LOGIC bằng trung bình UNGXU
hay nói cách khác là chấp nhận H0 ở mức sai lầm 5%
'''
# Out:
# '\nKết luận: do alpla = 0.05 và p-value = 0.3111 suy ra đủ dữ liệu để nói rằng triung bình LOGIC bằng trung bình UNGXU\nhay nói cách khác là chấp nhận H0 ở mức sai lầm 5%\n'

# %%
'''
Sinh viên làm tương tự:
kiểm tra xem trung binh UNGXU có bằng trung bình NGONNGU cho thí sinh khối C hay không
'''
dfkhoic=df.loc[df['KT']=='C']
stats.ttest_ind(dfkhoic['UNGXU'], dfkhoic['NGONNGU'], equal_var=True)
#Kết luận: do alpla = 0.05 và p-value = 0.014 suy ra không đủ dữ liệu để nói rằng trung bình LOGIC bằng trung bình UNGXU
#hay nói cách khác là không chấp nhận H0 ở mức sai lầm 5%
# Out:
# Ttest_indResult(statistic=-2.6321295849540447, pvalue=0.014085909192033959)

# %%
#hãy kiểm tra xem trung bình điểm toán học kì 2 lớp 12 có bằng 8.0
ztest(df['T6'], value=8.0)
#kết luận: k đủ dữ kiện đẻ nói rằng trung bình T6 không bằng 8
# Out:
# (-7.797828845339864, 6.298135014120743e-15)

# %%
'''
TWO Sample z-test
n>30
'''
# Out:
# '\nTWO Sample z-test\nn>30\n'

# %%
#Câu 4: kiểm tra xem điểm trung bình toán hk1 và hk2 năm lớp 12 có bằng nhau không
ztest(df['T5'],df['T6'], value=0)
#kết luận: đủ dữ kiện để kết luận rằng bằng nhau, chấp nhận (0.27 > 0.05)
# Out:
# (-1.094138573502891, 0.273894207026412)

# %%
#tự làm: kiểm tra xem trung bình LOGIC và UNGXU có bằng nhau hay không
ztest(df['LOGIC'],df['UNGXU'], value=0)
#kết luận: bác bỏ
# Out:
# (-4.172765180703833, 3.009250404643791e-05)

# %%
#Câu 5:
 #kiểm tra xem điểm toán hk1 và hk2 năm lớp 12 có tương quan không?
pearsonr(df['T5'],df['T6'])
#kết luạn trên mẫu: tương quan thuận, mức độ tương quan rất cao r = 0.7786831657869809
#suy diễn trên tổng thể:dữ liệu đủ để nói rằng T5 và T6 có tương quan với nhau với mức sai lầm là 5%
#với p-value = 1.4846407216273482e-21
# Out:
# PearsonRResult(statistic=0.7786831657869808, pvalue=1.4846407216274178e-21)

# %%
'''
ôn thi gk: 
 ĐỊNH LƯỢNG:
    one sample t-test
    one sample z-test
                    =>>H0: y=a
    
                    
    two sample t-test
    two sample z-test
                    =>H0: denta y=0
    
                    

    kiểm định pearson
                    =>H0: n=0
 
 ĐỊNH TÍNH:
    fishen (<30)
    chi-square (>30)
                    =>H0: độc lập

 ĐỊNH TÍNH + ĐỊNH LƯỢNG:
   anova
      - one way
      - two way
'''
# Out:
# '\nôn thi gk: \n ĐỊNH LƯỢNG:\n    one sample t-test\n    one sample z-test\n                    =>>H0: y=a\n    \n                    \n    two sample t-test\n    two sample z-test\n                    =>H0: denta y=0\n    \n                    \n\n    kiểm định pearson\n                    =>H0: n=0\n \n ĐỊNH TÍNH:\n    fishen (<30)\n    chi-square (>30)\n                    =>H0: độc lập\n\n ĐỊNH TÍNH + ĐỊNH LƯỢNG:\n   anova\n      - one way\n      - two way\n'

# %%
#kiểm tra xem T5 và LOGIC có tương quan không?
pearsonr(df['T5'],df['LOGIC'])
# Out:
# PearsonRResult(statistic=0.1846466122601273, pvalue=0.06590059130545516)

# %%
'''
fisher test:
mục đích: kiểm tra sự độc lập của 2 biến định tính dạng nhị phân 2x2
H0: không có sự khác biệt giữa 2 biến định tính
'''
# Out:
# '\nfisher test:\nmục đích: kiểm tra sự độc lập của 2 biến định tính dạng nhị phân 2x2\nH0: không có sự khác biệt giữa 2 biến định tính\n'

# %%
'''
Hãy kiểm tra xem có sự phụ thuộc nào giữa việc sinh viên có định hướng nghề nghiệp
và giới tính khi thí sinh đăng ký dự thi hay không
'''
crosdata=pd.crosstab(df['GT'], [df['HUONGNGHIEP']], rownames=['GT'], colnames=['HUONGNGHIEP'])
crosdata
# Out:
# HUONGNGHIEP  No  Yes
# GT
# F            23   25
# M            32   20

# %%
odd_ratio, p_value=stats.fisher_exact(crosdata)
print('odd ratio is: ' + str(odd_ratio))
print('p_value is: ' + str(p_value))
# Out:
# odd ratio is: 0.575
# p_value is: 0.22763927303454412

# %%
'''
Két luận: chấp nhận H0 vì p_value = 0.22763 > alpha = 0.05
tức là: đủ dữ liệu để nói rằng gới tính và việc định hướng nghề nghiệp là không có quan hệ gì cả
ở mức sai lầm 5%
'''
# Out:
# '\nKét luận: chấp nhận H0 vì p_value = 0.22763 > alpha = 0.05\ntức là: đủ dữ liệu để nói rằng gới tính và việc định hướng nghề nghiệp là không có quan hệ gì cả\nở mức sai lầm 5%\n'

# %%
'''
chi_square TEST
mục đích: kiểm tra sự độc lập của 2 biến định tính
H0: khong có sự khác biệt giữa 2 biến định tính
'''
# Out:
# '\nchi_square TEST\nmục đích: kiểm tra sự độc lập của 2 biến định tính\nH0: khong có sự khác biệt giữa 2 biến định tính\n'

# %%
'''
Hãy kiểm tra xem có sự phụ thuộc nào giữa khối thi và khu vực khi đăng ký dự thi hay khoong
'''
crosdata=pd.crosstab(df['KV'], [df['KT']], rownames=['KV'], colnames=['KT'])
crosdata
# Out:
# KT    A  A1  B  C  D1
# KV
# 1    29   2  8  8  13
# 2     9   0  0  2   8
# 2NT  11   4  1  4   1

# %%
stat, p, dof, expected= chi2_contingency(crosdata)

#interpnet p_value
alpha=0.05
print ("p value is: " + str(p))
if p<=alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is: 0.02012461887796485
# Dependent (reject H0)

# %%
''''
Két luận:bác bỏ H0 vì p_value = 0.0201246 < alpha = 0.05
tức là: không đủ dữ liệu để nói rằng KV và KT là độc lập hay có sự quan hệ giữa KT và KV
'''
# Out:
# "'\nKét luận:bác bỏ H0 vì p_value = 0.0201246 < alpha = 0.05\ntức là: không đủ dữ liệu để nói rằng KV và KT là độc lập hay có sự quan hệ giữa KT và KV\n"

# %%
#GT và KT
crosdata=pd.crosstab(df['GT'], [df['KT']], rownames=['GT'], colnames=['KT'])
crosdata
# Out:
# KT   A  A1  B  C  D1
# GT
# F   15   5  4  8  16
# M   34   1  5  6   6

# %%
stat, p, dof, expected= chi2_contingency(crosdata)

#interpnet p_value
alpha=0.05
print ("p value is: " + str(p))
if p<=alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is: 0.005044752209452435
# Dependent (reject H0)

# %%
'''
Két luận:bác bỏ H0 vì p_value = 0.0050 < alpha = 0.05
tức là: không đủ dữ liệu để nói rằng GT và KT là độc lập hay có sự quan hệ giữa GT và KV
'''
# Out:
# '\nKét luận:bác bỏ H0 vì p_value = 0.0050 < alpha = 0.05\ntức là: không đủ dữ liệu để nói rằng GT và KT là độc lập hay có sự quan hệ giữa GT và KV\n'

# %%
'''
one way anova
kiểm định anova one way
yêu cầu:
    1. Biến định lượng trên nhóm định tính
    2. Các biến định lượng trên từng nhóm theo phân phối chuẩn
    3. H0: giá trị trung bình dữ liệu định lượng trên từng nhómm định tính bằng nhau
'''
# Out:
# '\none way anova\nkiểm định anova one way\nyêu cầu:\n    1. Biến định lượng trên nhóm định tính\n    2. Các biến định lượng trên từng nhóm theo phân phối chuẩn\n    3. H0: giá trị trung bình dữ liệu định lượng trên từng nhómm định tính bằng nhau\n'

# %%
#Điểm toán hk2 lớp 12 có phụ thuộc vào GT không?
model=ols('T6 ~ GT', data=df).fit()
aov_table=sm.stats.anova_lm(model, type=1)
aov_table
# Out:
#             df     sum_sq  mean_sq         F    PR(>F)
# GT         1.0    1.55201  1.55201  0.833769  0.363426
# Residual  98.0  182.42109  1.86144       NaN       NaN

# %%
'''
trả lời: 
H0: mean(nhóm GT) bằng nhau
p-value = 0.363426 > 0.05 => chấp nhận
không phụ thuộc
kết luận: Điểm toán hk2 lớp 12 không phụ thuộc vào GT
'''
# Out:
# '\ntrả lời: \nH0: mean(nhóm GT) bằng nhau\np-value = 0.363426 > 0.05 => chấp nhận\nkhông phụ thuộc\nkết luận: Điểm toán hk2 lớp 12 không phụ thuộc vào GT\n'

# %%
#Điểm LOGIC có phụ thuộc vào KV không?
model=ols('LOGIC ~ KV', data=df).fit()
aov_table=sm.stats.anova_lm(model, type=1)
aov_table
# Out:
#             df      sum_sq   mean_sq         F    PR(>F)
# KV         2.0    6.053398  3.026699  2.790934  0.066299
# Residual  97.0  105.194102  1.084475       NaN       NaN

# %%
'''
trả lời: 
H0: mean(nhóm KV) bằng nhau
p-value = 0.066299 > 0.05 => chấp nhận
không phụ thuộc
kết luận: Điểm LOGIC không phụ thuộc vào KV
'''
# Out:
# '\ntrả lời: \nH0: mean(nhóm KV) bằng nhau\np-value = 0.066299 > 0.05 => chấp nhận\nkhông phụ thuộc\nkết luận: Điểm LOGIC không phụ thuộc vào KV\n'

# %%
#Điểm UNGXU có phụ thuộc vào KV không?
model=ols('UNGXU ~ KV', data=df).fit()
aov_table=sm.stats.anova_lm(model, type=1)
aov_table
# Out:
#             df     sum_sq   mean_sq         F    PR(>F)
# KV         2.0   9.398277  4.699138  4.655263  0.011735
# Residual  97.0  97.914223  1.009425       NaN       NaN

# %%
'''
trả lời: 
H0: mean(nhóm KV) bằng nhau
p-value = 0.011735 < 0.05 => không chấp nhận
phụ thuộc
kết luận: Điểm UNGXU phụ thuộc vào KV
'''
# Out:
# '\ntrả lời: \nH0: mean(nhóm KV) bằng nhau\np-value = 0.011735 < 0.05 => không chấp nhận\nphụ thuộc\nkết luận: Điểm UNGXU phụ thuộc vào KV\n'

# %%
'''
two way anova
kiểm định anova two way
yêu cầu: 
    1. biếng định lượng
    2. các biến định lượng trên từng nhóm theo phân phối chuẩn
    3. H0: trung bình các cột dữ liệu băng nhau
'''
# Out:
# '\ntwo way anova\nkiểm định anova two way\nyêu cầu: \n    1. biếng định lượng\n    2. các biến định lượng trên từng nhóm theo phân phối chuẩn\n    3. H0: trung bình các cột dữ liệu băng nhau\n'

# %%
#hãy cho biết điểm LOGIC có phụ thuộc vào loại GT trên từng nhóm KV hay không
# performing two anova
model=ols('LOGIC ~ GT + KV + GT: KV', data=df).fit()
result=sm.stats.anova_lm(model, type=2)

print(result)
# Out:
#             df     sum_sq   mean_sq         F    PR(>F)
# GT         1.0   3.998401  3.998401  3.853364  0.052602
# KV         2.0   8.561314  4.280657  4.125382  0.019173
# GT:KV      2.0   1.149707  0.574854  0.554002  0.576510
# Residual  94.0  97.538077  1.037639       NaN       NaN

# %%
'''
p-value = 0.052602 -> LOGIC độc lập theo nhóm GT
p-value = 0.019173 -> LOGIC phụ thuộc theo nhóm KV
p-value = 0.576510 -> LOGIC độc lập theo nhóm GT trên từng loại KV
'''
# Out:
# '\np-value = 0.052602 -> LOGIC độc lập theo nhóm GT\np-value = 0.019173 -> LOGIC phụ thuộc theo nhóm KV\np-value = 0.576510 -> LOGIC độc lập theo nhóm GT trên từng loại KV\n'

# %%
##hãy cho biết điểm NGONNGU có phụ thuộc theo nhóm KV trên từng loại KT hay không?
# performing two anova
model=ols('NGONNGU ~ KV + KT + KV: KT', data=df).fit()
result=sm.stats.anova_lm(model, type=2)

print(result)
# Out:
#             df      sum_sq    mean_sq          F        PR(>F)
# KV         2.0    4.237274   2.118637   1.416009  2.482173e-01
# KT         4.0   65.431143  16.357786  10.932867  3.150065e-07
# KV:KT      8.0    1.486487   0.185811   0.124188  9.981082e-01
# Residual  87.0  130.169640   1.496203        NaN           NaN

# %%
'''
p-value = 2.482173e-01 -> NGONNGU độc lập theo nhóm KV
p-value = 3.150065e-07 -> NGONNGU phụ thuộc theo nhóm KT
p-value = 9.981082e-01 -> NGONNGU độc lập theo nhóm KV trên từng loại KT
'''
# Out:
# '\np-value = 2.482173e-01 -> NGONNGU độc lập theo nhóm KV\np-value = 3.150065e-07 -> NGONNGU phụ thuộc theo nhóm KT\np-value = 9.981082e-01 -> NGONNGU độc lập theo nhóm KV trên từng loại KT\n'

# %%
# làm thêm: tạo bảng dữ liệu
'''import pandas as pd

data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 30, 35],
        'City': ['New York', 'London', 'Paris']}

df = pd.DataFrame(data)
print(df)
'''

'''
#xuất file 
# Lọc dữ liệu có DEALSIZE là Small
filtered_data = df[df['DEALSIZE'] == 'Small']

# Xuất dữ liệu vào file CSV
filtered_data.to_csv('small_dealsize_data.csv', index=False)
'''
# Out:
# "\n#xuất file \n# Lọc dữ liệu có DEALSIZE là Small\nfiltered_data = df[df['DEALSIZE'] == 'Small']\n\n# Xuất dữ liệu vào file CSV\nfiltered_data.to_csv('small_dealsize_data.csv', index=False)\n"
